# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("How many province Pakistan have?")
response.content
# Out:
# 'Pakistan has four provinces: Punjab, Sindh, Khyber Pakhtunkhwa (KP), and Balochistan.\n\nNote: In addition to these, Pakistan is also home to two autonomous/territorial regions—Azad Jammu and Kashmir (AJK) and Gilgit-Baltistan—and the Islamabad Capital Territory.'

# %%
from pprint import pprint
pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-ERNGEl0vDFiamJp0DruRPN6wZE7QT',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 907,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 832,
#                                                'rejected_prediction_tokens': 0,
#                                                'text_tokens': None},
#                  'prompt_tokens': 12,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cache_write_tokens': None,
#                                            'cached_tokens': 0,
#                                            'image_tokens': None,
#                                            'text_tokens': None},
#                  'total_tokens': 919}}

# %%
from langchain_google_genai import GoogleGenerativeAI
model = GoogleGenerativeAI(model="gemini-3.1-flash-lite")

# %%
response = model.invoke("List 5 big cities in the world")
print(response)
# Out:
# Here are 5 of the largest cities in the world by population:
#
# 1. **Tokyo, Japan**
# 2. **Delhi, India**
# 3. **Shanghai, China**
# 4. **São Paulo, Brazil**
# 5. **Mexico City, Mexico**

# %%
from langchain.agents import create_agent
agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent=create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage
response = agent.invoke(
    {"messages":[HumanMessage(content="Which breakfast is best for diabetic?")]}
)

# %%
from pprint import pprint
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Which breakfast is best for diabetic?', additional_kwargs={}, response_metadata={}, id='4e250ba1-e048-46c6-be76-082d455f235e'),
#               AIMessage(content='Best breakfast for diabetes is one that is balanced: include protein, fiber, healthy fats, and a moderate amount of low‑glycemic carbohydrates. This helps keep blood sugar steadier and may help with appetite and weight control. Individual targets vary, so it’s good to tailor portions with your clinician or a dietitian.\n\nGood breakfast ideas (diabetes-friendly)\n- Oatmeal with berries and nuts\n  - Rolled oats or steel-cut oats, unsweetened milk or water, fresh or frozen berries, a small handful of nuts or seeds. Add a side of plain Greek yogurt or a scoop of protein powder if you need more protein.\n  - Why it’s good: high in soluble fiber slows glucose rise; adds protein and healthy fats.\n- Veggie omelet with a slice of whole-grain toast\n  - Eggs or egg whites with spinach, peppers, mushrooms, onions; 1 slice whole-grain toast; optional avocado.\n  - Why it’s good: plenty of protein to start the day; fiber from whole grain; veggies add micronutrients.\n- Greek yogurt with berries and chia or flax\n  - Plain, low-fat or Greek yogurt, a handful of berries, 1–2 tablespoons chia or flax seeds; optional a sprinkle of nuts.\n  - Why it’s good: high protein; fiber from seeds and berries; low added sugar if you choose unsweetened yogurt.\n- Whole-grain toast with avocado and egg (or turkey/edamame spread)\n  - 1 slice whole-grain bread, nutritious toppings like avocado and a poached or boiled egg; optional tomato or leafy greens.\n  - Why it’s good: fiber + healthy fats + protein; keeps you fuller longer.\n- Chia pudding or overnight chia with unsweetened milk\n  - 3 tablespoons chia seeds soaked in unsweetened almond or dairy milk; top with berries or sliced kiwi.\n  - Why it’s good: very high fiber and healthy fats; can be made ahead.\n- Smoothie with protein and greens\n  - Spinach or kale, unsweetened milk or yogurt, a small portion of fruit (e.g., ½ cup berries or ¼ banana), and a scoop of protein powder or Greek yogurt; add a tablespoon of nut butter or seeds if desired.\n  - Why it’s good: quick and customizable; choose low-sugar fruit; protein helps stabilize sugar.\n\nHelpful tips\n- Prioritize protein and fiber at breakfast to help control blood sugar and hunger.\n- Choose whole, minimally processed carbs (oats, whole-grain bread, yogurt with no added sugar, fruit with fiber).\n- Limit items with added sugars (sweetened cereals, flavored yogurts with added sugar, pastries, fruit juice).\n- Keep portions appropriate to your meal plan. Many people aim for about 30–60 g total carbohydrates per meal, but targets vary—ask your dietitian what’s right for you.\n- If you take insulin or diabetes medications, be mindful of how breakfast foods affect your glucose and adjust under medical guidance.\n\nIf you’d like, tell me your type of diabetes, any dietary preferences or allergies, and roughly how many carbohydrates you aim for at breakfast. I can tailor 3–4 specific breakfast options with approximate carb counts to fit your plan.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2659, 'prompt_tokens': 13, 'total_tokens': 2672, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1984, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EROOxAui2U4YiURiIXTr1EXDSJnqX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0d013-def8-7e73-b3c7-e78e10589cac-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 2659, 'total_tokens': 2672, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1984}})]}

# %%
print(response['messages'][-1].content)
# Out:
# Best breakfast for diabetes is one that is balanced: include protein, fiber, healthy fats, and a moderate amount of low‑glycemic carbohydrates. This helps keep blood sugar steadier and may help with appetite and weight control. Individual targets vary, so it’s good to tailor portions with your clinician or a dietitian.
#
# Good breakfast ideas (diabetes-friendly)
# - Oatmeal with berries and nuts
#   - Rolled oats or steel-cut oats, unsweetened milk or water, fresh or frozen berries, a small handful of nuts or seeds. Add a side of plain Greek yogurt or a scoop of protein powder if you need more protein.
#   - Why it’s good: high in soluble fiber slows glucose rise; adds protein and healthy fats.
# - Veggie omelet with a slice of whole-grain toast
#   - Eggs or egg whites with spinach, peppers, mushrooms, onions; 1 slice whole-grain toast; optional avocado.
#   - Why it’s good: plenty of protein to start the day; fiber from whole grain; veggies add micronutrients.
# - Greek yogurt with berries and chia or flax
#   - Plain, low-fat or Greek yogurt, a handful of berries, 1–2 tablespoons chia or flax seeds; optional a sprinkle of nuts.
#   - Why it’s good: high protein; fiber from seeds and berries; low added sugar if you choose unsweetened yogurt.
# - Whole-grain toast with avocado and egg (or turkey/edamame spread)
#   - 1 slice whole-grain bread, nutritious toppings like avocado and a poached or boiled egg; optional tomato or leafy greens.
#   - Why it’s good: fiber + healthy fats + protein; keeps you fuller longer.
# - Chia pudding or overnight chia with unsweetened milk
#   - 3 tablespoons chia seeds soaked in unsweetened almond or dairy milk; top with berries or sliced kiwi.
#   - Why it’s good: very high fiber and healthy fats; can be made ahead.
# - Smoothie with protein and greens
#   - Spinach or kale, unsweetened milk or yogurt, a small portion of fruit (e.g., ½ cup berries or ¼ banana), and a scoop of protein powder or Greek yogurt; add a tablespoon of nut butter or seeds if desired.
#   - Why it’s good: quick and customizable; choose low-sugar fruit; protein helps stabilize sugar.
#
# Helpful tips
# - Prioritize protein and fiber at breakfast to help control blood sugar and hunger.
# - Choose whole, minimally processed carbs (oats, whole-grain bread, yogurt with no added sugar, fruit with fiber).
# - Limit items with added sugars (sweetened cereals, flavored yogurts with added sugar, pastries, fruit juice).
# - Keep portions appropriate to your meal plan. Many people aim for about 30–60 g total carbohydrates per meal, but targets vary—ask your dietitian what’s right for you.
# - If you take insulin or diabetes medications, be mindful of how breakfast foods affect your glucose and adjust under medical guidance.
#
# If you’d like, tell me your type of diabetes, any dietary preferences or allergies, and roughly how many carbohydrates you aim for at breakfast. I can tailor 3–4 specific breakfast options with approximate carb counts to fit your plan.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages":[HumanMessage(content="Which breakfast is best for diabetic?"),
                 AIMessage(content="Oatmeal and Wholegrain toast is best?"),
                 HumanMessage(content="Tell me how to live a healthy life?")]
    }
)

# %%
print(response)
# Out:
# {'messages': [HumanMessage(content='Which breakfast is best for diabetic?', additional_kwargs={}, response_metadata={}, id='5c5f9ac9-0b54-41f3-aecb-ae9814727de9'), AIMessage(content='Oatmeal and Wholegrain toast is best?', additional_kwargs={}, response_metadata={}, id='1f0ac686-d11b-43bf-90a1-ea3d0b32322e', tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='Tell me how to live a healthy life?', additional_kwargs={}, response_metadata={}, id='b62e1cb0-5887-42b3-ba16-9b0d37c1b044'), AIMessage(content='Great question. A healthy life is best built with small, consistent habits across several areas. Here’s a practical guide you can start using today.\n\nKey pillars\n- Nutrition\n  - Focus on balance: vegetables/fruit, lean proteins, whole grains, and healthy fats.\n  - Make most meals half veggies, one-quarter protein, one-quarter whole grains/carbs; add a small amount of healthy fat.\n  - Choose high-fiber, minimally processed carbs; limit added sugars and highly processed foods.\n  - Stay hydrated with water; limit sugary drinks and excessive caffeine/alcohol.\n- Physical activity\n  - Aim for about 150 minutes of moderate activity per week plus 2 days of strength training.\n  - Include movement every day: walk after meals, take stairs, stretch daily.\n- Sleep\n  - Target 7–9 hours per night. Keep a regular sleep schedule; create a calming wind-down routine.\n- Stress management\n  - Practice simple techniques: deep breathing, mindfulness, a hobby, or short breaks during the day.\n- Preventive care\n  - Keep up with routine checkups, vaccines, screenings, and dental/eye care as recommended.\n- Substance use and safety\n  - Don’t smoke; limit alcohol; use sun protection and safe practices in daily life.\n\nSimple habits you can start this week\n- Breakfast idea: oatmeal with berries and a handful of nuts, or yogurt with fruit and a sprinkle of seeds, or a veggie omelet with whole-grain toast.\n- A 10–15 minute daily walk after meals to help energy and digestion.\n- Swap one highly processed snack for a fruit, veggie sticks with hummus, or a small handful of nuts.\n- Set a consistent bedtime and cut screens 30–60 minutes before bed.\n\nIf you have a specific goal (weight loss, more energy, better blood sugar control, vegetarian or vegan preferences, etc.), tell me and I’ll tailor a plan for you.\n\nNote if you have a medical condition (like diabetes, high blood pressure, or heart disease): talk with your healthcare provider for personalized guidance. For diabetes especially, consider meal timing and carbohydrate quality, monitor blood sugar as advised, and don’t make drastic changes without professional input.\n\nWould you like a simple 1-week sample meal plan or a quick workout routine based on your age, fitness level, and preferences? If you share a bit about your situation, I can tailor it.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1717, 'prompt_tokens': 42, 'total_tokens': 1759, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1216, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-ERPZ3RFyL5JtunyU52OY2ncbJYqrS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0d058-1379-77f3-8f8f-198bf0ccd366-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 1717, 'total_tokens': 1759, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1216}})]}

# %%
print(response['messages'][-1].content)
# Out:
# Great question. A healthy life is best built with small, consistent habits across several areas. Here’s a practical guide you can start using today.
#
# Key pillars
# - Nutrition
#   - Focus on balance: vegetables/fruit, lean proteins, whole grains, and healthy fats.
#   - Make most meals half veggies, one-quarter protein, one-quarter whole grains/carbs; add a small amount of healthy fat.
#   - Choose high-fiber, minimally processed carbs; limit added sugars and highly processed foods.
#   - Stay hydrated with water; limit sugary drinks and excessive caffeine/alcohol.
# - Physical activity
#   - Aim for about 150 minutes of moderate activity per week plus 2 days of strength training.
#   - Include movement every day: walk after meals, take stairs, stretch daily.
# - Sleep
#   - Target 7–9 hours per night. Keep a regular sleep schedule; create a calming wind-down routine.
# - Stress management
#   - Practice simple techniques: deep breathing, mindfulness, a hobby, or short breaks during the day.
# - Preventive care
#   - Keep up with routine checkups, vaccines, screenings, and dental/eye care as recommended.
# - Substance use and safety
#   - Don’t smoke; limit alcohol; use sun protection and safe practices in daily life.
#
# Simple habits you can start this week
# - Breakfast idea: oatmeal with berries and a handful of nuts, or yogurt with fruit and a sprinkle of seeds, or a veggie omelet with whole-grain toast.
# - A 10–15 minute daily walk after meals to help energy and digestion.
# - Swap one highly processed snack for a fruit, veggie sticks with hummus, or a small handful of nuts.
# - Set a consistent bedtime and cut screens 30–60 minutes before bed.
#
# If you have a specific goal (weight loss, more energy, better blood sugar control, vegetarian or vegan preferences, etc.), tell me and I’ll tailor a plan for you.
#
# Note if you have a medical condition (like diabetes, high blood pressure, or heart disease): talk with your healthcare provider for personalized guidance. For diabetes especially, consider meal timing and carbohydrate quality, monitor blood sugar as advised, and don’t make drastic changes without professional input.
#
# Would you like a simple 1-week sample meal plan or a quick workout routine based on your age, fitness level, and preferences? If you share a bit about your situation, I can tailor it.

# %%
for token, metadata in agent.stream(
    {'messages':[HumanMessage(content="write 5 benefits of morning walk")]},
    stream_mode = 'messages'
):
    if token.content:
        print(token.content, end='', flush=True)
# Out:
# - Mood and mental well-being: Morning walks boost endorphins and exposure to daylight, reducing stress and improving mood.
#
# - Cardiovascular health: Regular walking improves circulation, lowers blood pressure, and supports heart health.
#
# - Weight management and metabolism: Burns calories, helps regulate appetite, and can improve insulin sensitivity.
#
# - Sleep and circadian rhythm: Morning light helps set your internal clock, leading to better sleep quality at night.
#
# - Energy, focus, and consistency: Increases blood flow to the brain, boosts daytime energy and productivity, and builds a healthy daily habit.
